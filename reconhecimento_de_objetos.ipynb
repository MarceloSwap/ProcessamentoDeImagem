# %%
#TRABALHO PROCESSAMENTO DE IMAGENS
#ALUNOS: MARCELO FERREIRA DE SOUZA E KHALIL DIAS SOUZA
#TURMA: BSI 2021

from keras.models import load_model  # TensorFlow is required for Keras to work
import cv2  # Install opencv-python
import numpy as np

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Load the model
model = load_model("keras_Model.h5", compile=False)

# Load the labels
class_names = open("labels.txt", "r").readlines()

# CAMERA can be 0 or 1 based on default camera of your computer
camera = cv2.VideoCapture(0)

while True:
    # Grab the webcamera's image.
    ret, image = camera.read()

    # Resize the raw image into (224-height,224-width) pixels
    image = cv2.resize(image, (224, 224), interpolation=cv2.INTER_AREA)

    # Show the image in a window
    cv2.imshow("Webcam Image", image)

    # Make the image a numpy array and reshape it to the models input shape.
    image = np.asarray(image, dtype=np.float32).reshape(1, 224, 224, 3)

    # Normalize the image array
    image = (image / 127.5) - 1

    # Predicts the model
    prediction = model.predict(image)
    index = np.argmax(prediction)
    class_name = class_names[index]
    confidence_score = prediction[0][index]

    # Print prediction and confidence score
    print("Class:", class_name[2:], end="")
    print("Confidence Score:", str(np.round(confidence_score * 100))[:-2], "%")

    # Listen to the keyboard for presses.
    keyboard_input = cv2.waitKey(1)

    # 27 is the ASCII for the esc key on your keyboard.
    if keyboard_input == 27:
        break

camera.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 1s 880ms/step
# Class: cubo
# Confidence Score: 66 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 37ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 37ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 37ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 38ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 38ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 38ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 34ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 69 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 67 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 68 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 67 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 66 %
# 1/1 [==============================] - 0s 39ms/step
# Class: cubo
# Confidence Score: 67 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 68 %
# 1/1 [==============================] - 0s 37ms/step
# Class: cubo
# Confidence Score: 69 %
# 1/1 [==============================] - 0s 46ms/step
# Class: cubo
# Confidence Score: 68 %
# 1/1 [==============================] - 0s 40ms/step
# Class: cubo
# Confidence Score: 68 %
# 1/1 [==============================] - 0s 37ms/step
# Class: cubo
# Confidence Score: 67 %
# 1/1 [==============================] - 0s 34ms/step
# Class: cubo
# Confidence Score: 68 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 69 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 69 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 67 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 67 %
# 1/1 [==============================] - 0s 33ms/step
# Class: cubo
# Confidence Score: 66 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 78 %
# 1/1 [==============================] - 0s 34ms/step
# Class: cubo
# Confidence Score: 69 %
# 1/1 [==============================] - 0s 37ms/step
# Class: cubo
# Confidence Score: 72 %
# 1/1 [==============================] - 0s 34ms/step
# Class: cubo
# Confidence Score: 72 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 41ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 33ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 32ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 33ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 33ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 33ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 32ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 33ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: cubo
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: cubo
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 33ms/step
# Class: cubo
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 34ms/step
# Class: cubo
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 34ms/step
# Class: cubo
# Confidence Score: 96 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 34ms/step
# Class: cubo
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 95 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 91 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 87 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 88 %
# 1/1 [==============================] - 0s 38ms/step
# Class: cubo
# Confidence Score: 89 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 82 %
# 1/1 [==============================] - 0s 37ms/step
# Class: chave
# Confidence Score: 81 %
# 1/1 [==============================] - 0s 37ms/step
# Class: chave
# Confidence Score: 94 %
# 1/1 [==============================] - 0s 36ms/step
# Class: chave
# Confidence Score: 89 %
# 1/1 [==============================] - 0s 40ms/step
# Class: relÃ³gio
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 33ms/step
# Class: relÃ³gio
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 44ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 32ms/step
# Class: relÃ³gio
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 33ms/step
# Class: relÃ³gio
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 32ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 33ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 33ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 33ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 33ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 81 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 45ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 33ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 38ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 33ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 33ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: relÃ³gio
# Confidence Score: 91 %
# 1/1 [==============================] - 0s 37ms/step
# Class: chave
# Confidence Score: 93 %
# 1/1 [==============================] - 0s 36ms/step
# Class: chave
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 35ms/step
# Class: chave
# Confidence Score: 87 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 79 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 85 %
# 1/1 [==============================] - 0s 37ms/step
# Class: cubo
# Confidence Score: 85 %
# 1/1 [==============================] - 0s 34ms/step
# Class: cubo
# Confidence Score: 72 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 80 %
# 1/1 [==============================] - 0s 38ms/step
# Class: cubo
# Confidence Score: 71 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 67 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 67 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 75 %
# 1/1 [==============================] - 0s 38ms/step
# Class: grampeador
# Confidence Score: 89 %
# 1/1 [==============================] - 0s 39ms/step
# Class: grampeador
# Confidence Score: 58 %
# 1/1 [==============================] - 0s 37ms/step
# Class: grampeador
# Confidence Score: 80 %
# 1/1 [==============================] - 0s 36ms/step
# Class: grampeador
# Confidence Score: 62 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: relÃ³gio
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 32ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: relÃ³gio
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 36ms/step
# Class: relÃ³gio
# Confidence Score: 46 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 67 %
# 1/1 [==============================] - 0s 37ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 36ms/step
# Class: grampeador
# Confidence Score: 44 %
# 1/1 [==============================] - 0s 34ms/step
# Class: cubo
# Confidence Score: 61 %
# 1/1 [==============================] - 0s 35ms/step
# Class: cubo
# Confidence Score: 72 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 72 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 82 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 82 %
# 1/1 [==============================] - 0s 40ms/step
# Class: unoGrogu
# Confidence Score: 73 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 74 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 95 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: unoGrogu
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 38ms/step
# Class: unoGrogu
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: unoGrogu
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: unoGrogu
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 96 %
# 1/1 [==============================] - 0s 38ms/step
# Class: unoGrogu
# Confidence Score: 94 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 79 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 79 %
# 1/1 [==============================] - 0s 34ms/step
# Class: unoGrogu
# Confidence Score: 77 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 84 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 95 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 95 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 93 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 86 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 84 %
# 1/1 [==============================] - 0s 38ms/step
# Class: unoGrogu
# Confidence Score: 86 %
# 1/1 [==============================] - 0s 38ms/step
# Class: unoGrogu
# Confidence Score: 92 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 85 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 84 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 93 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 96 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 89 %
# 1/1 [==============================] - 0s 34ms/step
# Class: unoGrogu
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 33ms/step
# Class: unoGrogu
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 98 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 34ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 52ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: unoGrogu
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 40ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 41ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: unoGrogu
# Confidence Score: 54 %
# 1/1 [==============================] - 0s 34ms/step
# Class: unoGrogu
# Confidence Score: 96 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: unoGrogu
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 39ms/step
# Class: unoGrogu
# Confidence Score: 79 %
# 1/1 [==============================] - 0s 38ms/step
# Class: unoGrogu
# Confidence Score: 95 %
# 1/1 [==============================] - 0s 40ms/step
# Class: unoGrogu
# Confidence Score: 93 %
# 1/1 [==============================] - 0s 38ms/step
# Class: unoGrogu
# Confidence Score: 95 %
# 1/1 [==============================] - 0s 39ms/step
# Class: unoGrogu
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 38ms/step
# Class: unoGrogu
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 40ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 95 %
# 1/1 [==============================] - 0s 41ms/step
# Class: unoGrogu
# Confidence Score: 97 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 94 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 75 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 92 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 58 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 70 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 95 %
# 1/1 [==============================] - 0s 39ms/step
# Class: unoGrogu
# Confidence Score: 93 %
# 1/1 [==============================] - 0s 38ms/step
# Class: unoGrogu
# Confidence Score: 92 %
# 1/1 [==============================] - 0s 39ms/step
# Class: unoGrogu
# Confidence Score: 90 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 34ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 33ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: unoGrogu
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 39ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 32ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 41ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 40ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 39ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 33ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 42ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 38ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 35ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 37ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 70ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 57ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 33ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 34ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 36ms/step
# Class: unoGrogu
# Confidence Score: 100 %
# 1/1 [==============================] - 0s 82ms/step
# Class: unoGrogu
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 57ms/step
# Class: unoGrogu
# Confidence Score: 99 %
# 1/1 [==============================] - 0s 73ms/step
# Class: unoGrogu
# Confidence Score: 92 %
# 1/1 [==============================] - 0s 129ms/step
# Class: unoGrogu
# Confidence Score: 51 %
# 1/1 [==============================] - 0s 57ms/step
# Class: unoGrogu
# Confidence Score: 59 %
# 1/1 [==============================] - 0s 120ms/step
# Class: chave
# Confidence Score: 44 %
# 1/1 [==============================] - 0s 36ms/step
# Class: cubo
# Confidence Score: 71 %
# 1/1 [==============================] - 0s 38ms/step
# Class: cubo
# Confidence Score: 70 %
# 1/1 [==============================] - 0s 32ms/step
# Class: cubo
# Confidence Score: 70 %
# 1/1 [==============================] - 0s 44ms/step
# Class: cubo
# Confidence Score: 72 %
# 1/1 [==============================] - 0s 41ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 42ms/step
# Class: cubo
# Confidence Score: 66 %
# 1/1 [==============================] - 0s 43ms/step
# Class: cubo
# ...
# 1/1 [==============================] - 0s 47ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 47ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 49ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 53ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 53ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 52ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 52ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 47ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 49ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 49ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 43ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 45ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 47ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 47ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 45ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 46ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 46ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 45ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 46ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 47ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 46ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 45ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 62 %
# 1/1 [==============================] - 0s 46ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 45ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 51ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 44ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 49ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 46ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 46ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 46ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 47ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 47ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 50ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 50ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 47ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 44ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 45ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 43ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 41ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 45ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 49ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 49ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 51ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 52ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 50ms/step
# Class: cubo
# Confidence Score: 66 %
# 1/1 [==============================] - 0s 52ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 66 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 66 %
# 1/1 [==============================] - 0s 46ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 47ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 47ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 47ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 56ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 47ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 47ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 49ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 46ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 46ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 50ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 49ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 50ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 47ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 49ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 62 %
# 1/1 [==============================] - 0s 49ms/step
# Class: cubo
# Confidence Score: 61 %
# 1/1 [==============================] - 0s 47ms/step
# Class: cubo
# Confidence Score: 62 %
# 1/1 [==============================] - 0s 51ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 65ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 51ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 50ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 50ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 47ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 52ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 51ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 53ms/step
# Class: cubo
# Confidence Score: 62 %
# 1/1 [==============================] - 0s 49ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 53ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 51ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 49ms/step
# Class: cubo
# Confidence Score: 66 %
# 1/1 [==============================] - 0s 45ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 49ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 47ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 50ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 50ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 50ms/step
# Class: cubo
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 49ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 48ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 50ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 47ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 50ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 43ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 50ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 51ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 47ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 49ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 49ms/step
# Class: cubo
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 49ms/step
# Class: cubo
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 46ms/step
# Class: cubo
# Confidence Score: 64 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 38
#      35 image = (image / 127.5) - 1
#      37 # Predicts the model
# ---> 38 prediction = model.predict(image)
#      39 index = np.argmax(prediction)
#      40 class_name = class_names[index]
#
# File ~\anaconda4\envs\bkp_env_teste\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda4\envs\bkp_env_teste\lib\site-packages\keras\src\engine\training.py:2596, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2587     except ValueError:
#    2588         warnings.warn(
#    2589             "Using Model.predict with MultiWorkerMirroredStrategy "
#    2590             "or TPUStrategy and AutoShardPolicy.FILE might lead to "
#    (...)
#    2593             stacklevel=2,
#    2594         )
# -> 2596 data_handler = data_adapter.get_data_handler(
#    2597     x=x,
#    2598     batch_size=batch_size,
#    2599     steps_per_epoch=steps,
#    2600     initial_epoch=0,
#    2601     epochs=1,
#    2602     max_queue_size=max_queue_size,
#    2603     workers=workers,
#    2604     use_multiprocessing=use_multiprocessing,
#    2605     model=self,
#    2606     steps_per_execution=self._steps_per_execution,
#    2607 )
#    2609 # Container that configures and calls `tf.keras.Callback`s.
#    2610 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~\anaconda4\envs\bkp_env_teste\lib\site-packages\keras\src\engine\data_adapter.py:1688, in get_data_handler(*args, **kwargs)
#    1686         return _ClusterCoordinatorExactEvalDataHandler(*args, **kwargs)
#    1687     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1688 return DataHandler(*args, **kwargs)
#
# File ~\anaconda4\envs\bkp_env_teste\lib\site-packages\keras\src\engine\data_adapter.py:1292, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute, pss_evaluation_shards)
#    1289     self._steps_per_execution = steps_per_execution
#    1291 adapter_cls = select_data_adapter(x, y)
# -> 1292 self._adapter = adapter_cls(
#    1293     x,
#    1294     y,
#    1295     batch_size=batch_size,
#    1296     steps=steps_per_epoch,
#    1297     epochs=epochs - initial_epoch,
#    1298     sample_weights=sample_weight,
#    1299     shuffle=shuffle,
#    1300     max_queue_size=max_queue_size,
#    1301     workers=workers,
#    1302     use_multiprocessing=use_multiprocessing,
#    1303     distribution_strategy=tf.distribute.get_strategy(),
#    1304     model=model,
#    1305     pss_evaluation_shards=pss_evaluation_shards,
#    1306 )
#    1308 strategy = tf.distribute.get_strategy()
#    1310 self._current_step = 0
#
# File ~\anaconda4\envs\bkp_env_teste\lib\site-packages\keras\src\engine\data_adapter.py:298, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     296 indices_dataset = tf.data.Dataset.range(1)
#     297 if shuffle != "batch":
# --> 298     indices_dataset = indices_dataset.repeat(epochs)
#     300 def permutation(_):
#     301     # It turns out to be more performant to make a new set of indices
#     302     # rather than reusing the same range Tensor. (presumably because of
#     303     # buffer forwarding.)
#     304     indices = tf.range(num_samples, dtype=tf.int64)
#
# File ~\anaconda4\envs\bkp_env_teste\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:1341, in DatasetV2.repeat(self, count, name)
#    1337 # Loaded lazily due to a circular dependency (dataset_ops -> repeat_op ->
#    1338 # dataset_ops).
#    1339 # pylint: disable=g-import-not-at-top,protected-access,redefined-outer-name
#    1340 from tensorflow.python.data.ops import repeat_op
# -> 1341 return repeat_op._repeat(self, count, name)
#
# File ~\anaconda4\envs\bkp_env_teste\lib\site-packages\tensorflow\python\data\ops\repeat_op.py:25, in _repeat(input_dataset, count, name)
#      24 def _repeat(input_dataset, count, name):  # pylint: disable=unused-private-name
# ---> 25   return _RepeatDataset(input_dataset, count, name)
#
# File ~\anaconda4\envs\bkp_env_teste\lib\site-packages\tensorflow\python\data\ops\repeat_op.py:40, in _RepeatDataset.__init__(self, input_dataset, count, name)
#      37   self._count = ops.convert_to_tensor(
#      38       count, dtype=dtypes.int64, name="count")
#      39 self._name = name
# ---> 40 variant_tensor = gen_dataset_ops.repeat_dataset(
#      41     input_dataset._variant_tensor,  # pylint: disable=protected-access
#      42     count=self._count,
#      43     **self._common_args)
#      44 super().__init__(input_dataset, variant_tensor)
#
# File ~\anaconda4\envs\bkp_env_teste\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:6451, in repeat_dataset(input_dataset, count, output_types, output_shapes, metadata, name)
#    6449 if tld.is_eager:
#    6450   try:
# -> 6451     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    6452       _ctx, "RepeatDataset", name, input_dataset, count, "output_types",
#    6453       output_types, "output_shapes", output_shapes, "metadata", metadata)
#    6454     return _result
#    6455   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
